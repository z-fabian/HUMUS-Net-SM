# %%
# !python humus_examples/train_humus_stanford.py --data_path '/root/datasets/Stanford_3D_FSE_knee/converted' \
#                                                  --default_root_dir '/root/models/test' \
#                                                  --config_file '/root/HUMUS-Net_release/humus_examples/experiments/stanford3d/humus_baseline.yaml' \
#                                                  --train_val_seed 0 \
#                                                  --gpus 4

# !python humus_examples/train_humus_fastmri.py --data_path '/data/fastMRI/knee' \
#                                                  --default_root_dir '/root/models/test' \
#                                                  --config_file '/root/HUMUS-Net_release/humus_examples/experiments/fastmri/humus_test.yaml' \
#                                                  --gpus 8

# !python humus_examples/eval_humus_fastmri.py --data_path '/data/fastMRI/knee' \
                                                 --checkpoint_file '/root/humus_saved_models/humusnet_fastmri_knee_8x_train.ckpt' \
                                                 --gpus 4

# !python humus_examples/eval_humus_stanford.py --data_path '/root/datasets/Stanford_3D_FSE_knee/converted' \
#                                                  --checkpoint_file '/root/models/moe_baseline_stanford3d/seed0/lightning_logs/version_0/checkpoints/last.ckpt' \
#                                                  --train_val_seed 0 \
#                                                  --train_val_split 0.8 \
#                                                  --gpus 2

# python3 humus_examples/eval_humus_fastmri.py --data_path '/media/zalanHDD/Backup Storage/datasets/fastMRI/knee' \
#                                                  --default_root_dir '/home/zalan/models/test2' \
#                                                  --checkpoint_file '/home/zalan/humus_saved_models/humusnet_fastmri_knee_8x_train.ckpt' \
#                                                  --gpus 4

# python3 humus_examples/train_humus_stanford.py --data_path '/home/zalan/datasets/Stanford_3D_FSE_knee/converted' \
#                                                  --default_root_dir '/home/zalan/models/test2' \
#                                                  --config_file '/home/zalan/HUMUS-Net_release/humus_examples/experiments/stanford3d/humus_baseline.yaml' \
#                                                  --train_val_seed 0 \
#                                                  --gpus 4
# Out:
# Global seed set to 42
# /usr/local/lib/python3.6/dist-packages/torch/functional.py:445: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2157.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# Global seed set to 42
# /usr/local/lib/python3.6/dist-packages/torch/functional.py:445: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2157.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Global seed set to 42
# ...
